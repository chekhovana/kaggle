# %%
# !pip install -q fancyimpute

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/kaggle/house_pricing'
# Out:
# /content/drive/MyDrive/Colab Notebooks/kaggle/house_pricing

# %%
from common import *
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ####Read data

# %%
x_train, y_train, x_test = read_data()
x_total = pd.concat((x_train, x_test))
x_train.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# Id                                    ...
# 1           60       RL         65.0  ...    2008       WD        Normal
# 2           20       RL         80.0  ...    2007       WD        Normal
# 3           60       RL         68.0  ...    2008       WD        Normal
# 4           70       RL         60.0  ...    2006       WD       Abnorml
# 5           60       RL         84.0  ...    2008       WD        Normal
#
# [5 rows x 79 columns]

# %%
x_train.describe()
# Out:
#         MSSubClass  LotFrontage  ...       MoSold       YrSold
# count  1460.000000  1201.000000  ...  1460.000000  1460.000000
# mean     56.897260    70.049958  ...     6.321918  2007.815753
# std      42.300571    24.284752  ...     2.703626     1.328095
# min      20.000000    21.000000  ...     1.000000  2006.000000
# 25%      20.000000    59.000000  ...     5.000000  2007.000000
# 50%      50.000000    69.000000  ...     6.000000  2008.000000
# 75%      70.000000    80.000000  ...     8.000000  2009.000000
# max     190.000000   313.000000  ...    12.000000  2010.000000
#
# [8 rows x 36 columns]

# %% [markdown]
# ---
# ####Explore column types

# %%
columns_cat = x_total.columns[x_total.dtypes == object]
columns_num = x_total.columns[x_total.dtypes != object]

print('Number of numeric features:', len(columns_num))
print('Number of categorical features:', len(columns_cat))
# Out:
# Number of numeric features: 36
# Number of categorical features: 43

# %% [markdown]
# ---
# ## Explore numeric features

# %% [markdown]
# ### Distributions

# %%
x_train[columns_num].hist(figsize = (12, 28), layout = (10, 4), bins = 20, 
                  color = 'lightsteelblue', edgecolor = 'firebrick', linewidth = 1.5)
plt.tight_layout();

# %%
columns_discrete = ['OverallQual', 'OverallCond', 'BsmtFullBath', 'FullBath', 
    'HalfBath', 'BedroomAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 
    'MoSold', 'YrSold']
columns_continuous = set(columns_num) - set(columns_discrete)

fig = plt.figure(figsize = (12, 27))
flierprops = dict(marker='o', markerfacecolor = 'r', markeredgecolor = 'k', 
    markersize = 9)

for index, column in enumerate(columns_continuous):
    plt.subplot(7, 4, index + 1)
    sns.boxplot(x=column, data=x_train, color='mediumseagreen', flierprops=flierprops)
    plt.xticks(rotation = 90)
    
fig.tight_layout()

# %% [markdown]
# We can observe that:
#
# * Some feautures, such as 'LowQualFinSF' and 'PoolArea', display low variance (or variability), which means that they are close to being constant. Therefore, they do not provide any information to a ML model for learning the patterns in the data and they should be removed,
# * Different attributes have different scales and we need to take care of that at the processing stage,
# * Most attributes are continuous (e.g. 'LotFrontage'), but there are some discrete ones ('FullBath', 'YrSold', etc.), and
# * Most of the attributes suffer from outliers
# * For some attributes, the min, max and the interquantile range 'collapse' into a line. That's because these attributes consist of mostly one value (for example, see '3SsnPorch' and 'PoolArea').

# %% [markdown]
# ### Missing values

# %%
def missing_percentage(df):
    total = df.isnull().sum().sort_values(
        ascending=False)[df.isnull().sum().sort_values(ascending=False) != 0]
    percent = (df.isnull().sum().sort_values(ascending=False) / len(df) *
               100)[(df.isnull().sum().sort_values(ascending=False) / len(df) *
                     100) != 0]
    return pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])


df_missing = missing_percentage(x_total[columns_num])
fig, ax = plt.subplots(figsize=(20, 5))
sns.barplot(x=df_missing.index, y='Percent', data=df_missing, palette='Reds_r')
plt.xticks(rotation=90)
plt.show()
pd.set_option('precision', 4)
display(df_missing.T.style.background_gradient(cmap='Reds', axis=1))
# Out:
# <style  type="text/css" >
# #T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col0,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col0{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col1,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col1{
#             background-color:  #fca285;
#             color:  #000000;
#         }#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col2,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col2{
#             background-color:  #ffeee6;
#             color:  #000000;
#         }#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col3,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col4,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col5,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col6,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col7,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col8,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col9,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col10,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col3,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col4,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col5,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col6,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col7,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col8,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col9,#T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col10{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >LotFrontage</th>        <th class="col_heading level0 col1" >GarageYrBlt</th>        <th class="col_heading level0 col2" >MasVnrArea</th>        <th class="col_heading level0 col3" >BsmtHalfBath</th>        <th class="col_heading level0 col4" >BsmtFullBath</th>        <th class="col_heading level0 col5" >GarageArea</th>        <th class="col_heading level0 col6" >BsmtFinSF1</th>        <th class="col_heading level0 col7" >BsmtFinSF2</th>        <th class="col_heading level0 col8" >BsmtUnfSF</th>        <th class="col_heading level0 col9" >TotalBsmtSF</th>        <th class="col_heading level0 col10" >GarageCars</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002level0_row0" class="row_heading level0 row0" >Total</th>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col0" class="data row0 col0" >486.0000</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col1" class="data row0 col1" >159.0000</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col2" class="data row0 col2" >23.0000</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col3" class="data row0 col3" >2.0000</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col4" class="data row0 col4" >2.0000</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col5" class="data row0 col5" >1.0000</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col6" class="data row0 col6" >1.0000</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col7" class="data row0 col7" >1.0000</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col8" class="data row0 col8" >1.0000</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col9" class="data row0 col9" >1.0000</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row0_col10" class="data row0 col10" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002level0_row1" class="row_heading level0 row1" >Percent</th>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col0" class="data row1 col0" >16.6495</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col1" class="data row1 col1" >5.4471</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col2" class="data row1 col2" >0.7879</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col3" class="data row1 col3" >0.0685</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col4" class="data row1 col4" >0.0685</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col5" class="data row1 col5" >0.0343</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col6" class="data row1 col6" >0.0343</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col7" class="data row1 col7" >0.0343</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col8" class="data row1 col8" >0.0343</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col9" class="data row1 col9" >0.0343</td>
#                         <td id="T_647ee0da_78eb_11ec_9fad_0242ac1c0002row1_col10" class="data row1 col10" >0.0343</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Correlation

# %%
sns.set(font_scale=0.8)
xy_train = x_train.copy()
xy_train['SalePrice'] = y_train
correlation_train = xy_train.corr()
mask = np.triu(correlation_train.corr())
plt.figure(figsize=(15, 15))
_ = sns.heatmap(correlation_train,
            annot=True,
            fmt='.1f',
            cmap='coolwarm',
            square=True,
            mask=mask,
            linewidths=1,
            cbar=False)

# %% [markdown]
# ---
# ## Explore categorical features

# %% [markdown]
# ### Distributions

# %%
fig = plt.figure(figsize = (12, 37))

for index, column in enumerate(columns_cat):
    
    plt.subplot(11, 4, index + 1)
    sns.countplot(x = column, data = x_train, palette = 'Set2')
    plt.xticks(rotation = 90)
    
fig.tight_layout();

# %% [markdown]
# ### Missing values

# %%
df_missing = missing_percentage(x_total[columns_cat])
fig, ax = plt.subplots(figsize=(12, 5))
sns.barplot(x=df_missing.index, y='Percent', data=df_missing, palette='Reds_r')
plt.xticks(rotation=90)
plt.show()
pd.set_option('precision', 4)
display(df_missing.T.style.background_gradient(cmap='Reds', axis=1))
# Out:
# <style  type="text/css" >
# #T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col0,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col0{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col1,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col1{
#             background-color:  #77040f;
#             color:  #f1f1f1;
#         }#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col2,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col2{
#             background-color:  #860811;
#             color:  #f1f1f1;
#         }#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col3,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col3{
#             background-color:  #b91419;
#             color:  #f1f1f1;
#         }#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col4,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col4{
#             background-color:  #fb6e4e;
#             color:  #000000;
#         }#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col5,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col6,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col7,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col8,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col5,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col6,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col7,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col8{
#             background-color:  #ffece4;
#             color:  #000000;
#         }#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col9,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col10,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col11,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col9,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col10,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col11{
#             background-color:  #fff0e9;
#             color:  #000000;
#         }#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col12,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col13,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col12,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col13{
#             background-color:  #fff1ea;
#             color:  #000000;
#         }#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col14,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col14{
#             background-color:  #fff4ee;
#             color:  #000000;
#         }#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col15,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col16,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col17,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col18,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col19,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col20,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col21,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col22,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col15,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col16,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col17,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col18,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col19,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col20,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col21,#T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col22{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PoolQC</th>        <th class="col_heading level0 col1" >MiscFeature</th>        <th class="col_heading level0 col2" >Alley</th>        <th class="col_heading level0 col3" >Fence</th>        <th class="col_heading level0 col4" >FireplaceQu</th>        <th class="col_heading level0 col5" >GarageCond</th>        <th class="col_heading level0 col6" >GarageQual</th>        <th class="col_heading level0 col7" >GarageFinish</th>        <th class="col_heading level0 col8" >GarageType</th>        <th class="col_heading level0 col9" >BsmtCond</th>        <th class="col_heading level0 col10" >BsmtExposure</th>        <th class="col_heading level0 col11" >BsmtQual</th>        <th class="col_heading level0 col12" >BsmtFinType2</th>        <th class="col_heading level0 col13" >BsmtFinType1</th>        <th class="col_heading level0 col14" >MasVnrType</th>        <th class="col_heading level0 col15" >MSZoning</th>        <th class="col_heading level0 col16" >Functional</th>        <th class="col_heading level0 col17" >Utilities</th>        <th class="col_heading level0 col18" >Electrical</th>        <th class="col_heading level0 col19" >KitchenQual</th>        <th class="col_heading level0 col20" >SaleType</th>        <th class="col_heading level0 col21" >Exterior2nd</th>        <th class="col_heading level0 col22" >Exterior1st</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002level0_row0" class="row_heading level0 row0" >Total</th>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col0" class="data row0 col0" >2909.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col1" class="data row0 col1" >2814.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col2" class="data row0 col2" >2721.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col3" class="data row0 col3" >2348.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col4" class="data row0 col4" >1420.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col5" class="data row0 col5" >159.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col6" class="data row0 col6" >159.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col7" class="data row0 col7" >159.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col8" class="data row0 col8" >157.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col9" class="data row0 col9" >82.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col10" class="data row0 col10" >82.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col11" class="data row0 col11" >81.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col12" class="data row0 col12" >80.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col13" class="data row0 col13" >79.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col14" class="data row0 col14" >24.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col15" class="data row0 col15" >4.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col16" class="data row0 col16" >2.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col17" class="data row0 col17" >2.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col18" class="data row0 col18" >1.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col19" class="data row0 col19" >1.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col20" class="data row0 col20" >1.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col21" class="data row0 col21" >1.0000</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row0_col22" class="data row0 col22" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002level0_row1" class="row_heading level0 row1" >Percent</th>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col0" class="data row1 col0" >99.6574</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002row1_col1" class="data row1 col1" >96.4029</td>
#                         <td id="T_6ccf711e_78eb_11ec_9fad_0242ac1c0002r

# %% [markdown]
# ### Correlatioin

# %%
x = x_train.copy()
corr = {}
for col in columns_cat:
    x.fillna('None', inplace=True)
    cat_values = {}
    for val in x[col].unique():
        cat_values[val] = y_train[x[col] == val].values
    corr[col] = 1 - stats.kruskal(*list(cat_values.values())).pvalue

corr = sorted(corr.items(), key=lambda x: x[1], reverse=False)
df_corr = pd.DataFrame(data=corr, columns=['Feature', 'PValue'])
df_corr = df_corr.set_index('Feature')
display(df_corr.T.style.background_gradient(cmap='Reds', axis=1))
# Out:
# <style  type="text/css" >
# #T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col0{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col1{
#             background-color:  #d01d1f;
#             color:  #f1f1f1;
#         }#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col2{
#             background-color:  #bf151b;
#             color:  #f1f1f1;
#         }#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col3{
#             background-color:  #ad1117;
#             color:  #f1f1f1;
#         }#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col4{
#             background-color:  #7a0510;
#             color:  #f1f1f1;
#         }#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col5{
#             background-color:  #73030f;
#             color:  #f1f1f1;
#         }#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col6{
#             background-color:  #6f020e;
#             color:  #f1f1f1;
#         }#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col7,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col8,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col9,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col10,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col11,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col12,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col13,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col14,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col15,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col16,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col17,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col18,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col19,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col20,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col21,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col22,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col23,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col24,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col25,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col26,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col27,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col28,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col29,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col30,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col31,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col32,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col33,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col34,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col35,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col36,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col37,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col38,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col39,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col40,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col41,#T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col42{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }</style><table id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="index_name level0" >Feature</th>        <th class="col_heading level0 col0" >Utilities</th>        <th class="col_heading level0 col1" >LandSlope</th>        <th class="col_heading level0 col2" >PoolQC</th>        <th class="col_heading level0 col3" >Street</th>        <th class="col_heading level0 col4" >MiscFeature</th>        <th class="col_heading level0 col5" >Condition2</th>        <th class="col_heading level0 col6" >RoofMatl</th>        <th class="col_heading level0 col7" >Functional</th>        <th class="col_heading level0 col8" >Heating</th>        <th class="col_heading level0 col9" >LotConfig</th>        <th class="col_heading level0 col10" >RoofStyle</th>        <th class="col_heading level0 col11" >LandContour</th>        <th class="col_heading level0 col12" >ExterCond</th>        <th class="col_heading level0 col13" >Alley</th>        <th class="col_heading level0 col14" >BsmtFinType2</th>        <th class="col_heading level0 col15" >Condition1</th>        <th class="col_heading level0 col16" >BldgType</th>        <th class="col_heading level0 col17" >Fence</th>        <th class="col_heading level0 col18" >MSZoning</th>        <th class="col_heading level0 col19" >LotShape</th>        <th class="col_heading level0 col20" >Neighborhood</th>        <th class="col_heading level0 col21" >HouseStyle</th>        <th class="col_heading level0 col22" >Exterior1st</th>        <th class="col_heading level0 col23" >Exterior2nd</th>        <th class="col_heading level0 col24" >MasVnrType</th>        <th class="col_heading level0 col25" >ExterQual</th>        <th class="col_heading level0 col26" >Foundation</th>        <th class="col_heading level0 col27" >BsmtQual</th>        <th class="col_heading level0 col28" >BsmtCond</th>        <th class="col_heading level0 col29" >BsmtExposure</th>        <th class="col_heading level0 col30" >BsmtFinType1</th>        <th class="col_heading level0 col31" >HeatingQC</th>        <th class="col_heading level0 col32" >CentralAir</th>        <th class="col_heading level0 col33" >Electrical</th>        <th class="col_heading level0 col34" >KitchenQual</th>        <th class="col_heading level0 col35" >FireplaceQu</th>        <th class="col_heading level0 col36" >GarageType</th>        <th class="col_heading level0 col37" >GarageFinish</th>        <th class="col_heading level0 col38" >GarageQual</th>        <th class="col_heading level0 col39" >GarageCond</th>        <th class="col_heading level0 col40" >PavedDrive</th>        <th class="col_heading level0 col41" >SaleType</th>        <th class="col_heading level0 col42" >SaleCondition</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002level0_row0" class="row_heading level0 row0" >PValue</th>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col0" class="data row0 col0" >0.4767</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col1" class="data row0 col1" >0.8605</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col2" class="data row0 col2" >0.8882</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col3" class="data row0 col3" >0.9199</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col4" class="data row0 col4" >0.9794</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col5" class="data row0 col5" >0.9870</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col6" class="data row0 col6" >0.9914</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col7" class="data row0 col7" >1.0000</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col8" class="data row0 col8" >1.0000</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col9" class="data row0 col9" >1.0000</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col10" class="data row0 col10" >1.0000</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col11" class="data row0 col11" >1.0000</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col12" class="data row0 col12" >1.0000</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col13" class="data row0 col13" >1.0000</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col14" class="data row0 col14" >1.0000</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col15" class="data row0 col15" >1.0000</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col16" class="data row0 col16" >1.0000</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col17" class="data row0 col17" >1.0000</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9fad_0242ac1c0002row0_col18" class="data row0 col18" >1.0000</td>
#                         <td id="T_7a9c2e5e_78eb_11ec_9

# %% [markdown]
# ---
# ## Explore the target variable

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (12, 4))

sns.histplot(data=y_train, color='darkslateblue', ax = ax1, kde=True)
sns.boxplot(x=y_train, color='slateblue', ax = ax2)
ax2.set_xticks([0, 200000, 400000, 600000])

#skewness and kurtosis
print('Skewness: {}'.format( np.round(y_train.skew(), 2) ))
print('Kurtosis: {}'.format( np.round(y_train.kurt(), 2) ))
# Out:
# Skewness: 1.88
# Kurtosis: 6.54

# %% [markdown]
# Our target variable deviates from the symmetrical bell curve we would expect from a normal distribution. Specifically, it is right-skewed (similar terms: right-tailed or skewed to the right) since the right tail is longer.
#
# This could be a problem since many ML algorithms don't do well with data that are not normally distributed. We can correct for this by performing a **log-transformation** of the target variable:

# %%
y_train_transformed = np.log1p(y_train)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (12, 4))

sns.histplot(data=y_train_transformed, color = 'darkslateblue', ax = ax1, kde=True)
sns.boxplot(x=y_train_transformed, color = 'darkslateblue', ax = ax2)

#skewness and kurtosis
print('Skewness: {}'.format( np.round(y_train_transformed.skew(), 2) ))
print('Kurtosis: {}'.format( np.round(y_train_transformed.kurt(), 2) ))
# Out:
# Skewness: 0.12
# Kurtosis: 0.81
